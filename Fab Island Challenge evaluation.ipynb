# %%
import pandas as pd
import numpy as np

# %%
# Import datasets
Kopernik = pd.read_csv('Kopernik.CSV')
BambooU = pd.read_csv('BambooU.CSV')
NuCycle = pd.read_csv('NuCycle.CSV')
IDEP = pd.read_csv('IDEP.CSV')
Hydropods = pd.read_csv('Hydropods.CSV')
Prakash = pd.read_csv('Prakash.CSV')
PP = pd.read_csv('PP.CSV')
PE = pd.read_csv('PE.CSV')
Printridi = pd.read_csv('Printridi.CSV')

# %%
# Deleting unecessary columns
Kopernik.drop(['Taal', 'ID', 'Begintijd', 'Tijd van voltooien', 'E-mail', 'Naam', 'Column', 'I (full name)'], inplace=True, axis=1)
BambooU.drop(['Taal', 'ID', 'Begintijd', 'Tijd van voltooien', 'E-mail', 'Naam', 'Column', 'I (full name)'], inplace=True, axis=1)
NuCycle.drop(['Taal', 'ID', 'Begintijd', 'Tijd van voltooien', 'E-mail', 'Naam', 'Column', 'I (full name)'], inplace=True, axis=1)
IDEP.drop(['Taal', 'ID', 'Begintijd', 'Tijd van voltooien', 'E-mail', 'Naam', 'Column', 'I (full name)'], inplace=True, axis=1)
Hydropods.drop(['Taal', 'ID', 'Begintijd', 'Tijd van voltooien', 'E-mail', 'Naam', 'Column', 'I (full name)'], inplace=True, axis=1)
Prakash.drop(['Taal', 'ID', 'Begintijd', 'Tijd van voltooien', 'E-mail', 'Naam', 'Column', 'I (full name)'], inplace=True, axis=1)
PP.drop(['Taal', 'ID', 'Begintijd', 'Tijd van voltooien', 'E-mail', 'Naam', 'Column', 'I (full name)'], inplace=True, axis=1)
PE.drop(['Taal', 'ID', 'Begintijd', 'Tijd van voltooien', 'E-mail', 'Naam', 'Column', 'I (full name)'], inplace=True, axis=1)
Printridi.drop(['Taal', 'ID', 'Begintijd', 'Tijd van voltooien', 'E-mail', 'Naam', 'Column', 'I (full name)'], inplace=True, axis=1)

# Shortening and rearanging column names
Kopernik.rename({'Please indicate your current occupation.': 'Occupation', 'Are you part of Bali Fab Fest as speaker/host/organisation.': 'BFF_Team', 'Please select the gender you identify as.': 'Gender', 'What is your nationality?': 'Nationality', 'Do you think the project is well balanced? Why?': 'Balanced?', 'Can you give a short explanation?': 'Explanation'}, axis=1, inplace=True)
BambooU.rename({'Please indicate your current occupation.': 'Occupation', 'Are you part of Bali Fab Fest as speaker/host/organisation.': 'BFF_Team', 'Please select the gender you identify as.': 'Gender', 'What is your nationality?': 'Nationality', 'Do you think the project is well balanced? Why?': 'Balanced?', 'Can you give a short explanation?': 'Explanation'}, axis=1, inplace=True)
NuCycle.rename({'Please indicate your current occupation.': 'Occupation', 'Are you part of Bali Fab Fest as speaker/host/organisation.': 'BFF_Team', 'Please select the gender you identify as.': 'Gender', 'What is your nationality?': 'Nationality', 'Do you think the project is well balanced? Why?': 'Balanced?', 'Can you give a short explanation?': 'Explanation'}, axis=1, inplace=True)
IDEP.rename({'Please indicate your current occupation.': 'Occupation', 'Are you part of Bali Fab Fest as speaker/host/organisation.': 'BFF_Team', 'Please select the gender you identify as.': 'Gender', 'What is your nationality?': 'Nationality', 'Do you think the project is well balanced? Why?': 'Balanced?', 'Can you give a short explanation?': 'Explanation'}, axis=1, inplace=True)
Hydropods.rename({'Please indicate your current occupation.': 'Occupation', 'Are you part of Bali Fab Fest as speaker/host/organisation.': 'BFF_Team', 'Please select the gender you identify as.': 'Gender', 'What is your nationality?': 'Nationality', 'Do you think the project is well balanced? Why?': 'Balanced?', 'Can you give a short explanation?': 'Explanation'}, axis=1, inplace=True)
Prakash.rename({'Please indicate your current occupation.': 'Occupation', 'Are you part of Bali Fab Fest as speaker/host/organisation.': 'BFF_Team', 'Please select the gender you identify as.': 'Gender', 'What is your nationality?': 'Nationality', 'Do you think the project is well balanced? Why?': 'Balanced?', 'Can you give a short explanation?': 'Explanation'}, axis=1, inplace=True)
PP.rename({'Please indicate your current occupation.': 'Occupation', 'Are you part of Bali Fab Fest as speaker/host/organisation.': 'BFF_Team', 'Please select the gender you identify as.': 'Gender', 'What is your nationality?': 'Nationality', 'Do you think the project is well balanced? Why?': 'Balanced?', 'Can you give a short explanation?': 'Explanation'}, axis=1, inplace=True)
PE.rename({'Please indicate your current occupation.': 'Occupation', 'Are you part of Bali Fab Fest as speaker/host/organisation.': 'BFF_Team', 'Please select the gender you identify as.': 'Gender', 'What is your nationality?': 'Nationality', 'Do you think the project is well balanced? Why?': 'Balanced?', 'Can you give a short explanation?': 'Explanation'}, axis=1, inplace=True)
Printridi.rename({'Please indicate your current occupation.': 'Occupation', 'Are you part of Bali Fab Fest as speaker/host/organisation.': 'BFF_Team', 'Please select the gender you identify as.': 'Gender', 'What is your nationality?': 'Nationality', 'Do you think the project is well balanced? Why?': 'Balanced?', 'Can you give a short explanation?': 'Explanation'}, axis=1, inplace=True)

# Rearange columns
Kopernik = Kopernik.reindex(columns=["Occupation", "BFF_Team", "Gender", "Nationality", "Human wellbeing", "Community development", "Environmental regeneration", "Balanced?", "Ingenious technology", "Globally scalable", "Out-of-the-box", "Explanation"])
BambooU = BambooU.reindex(columns=["Occupation", "BFF_Team", "Gender", "Nationality", "Human wellbeing", "Community development", "Environmental regeneration", "Balanced?", "Ingenious technology", "Globally scalable", "Out-of-the-box", "Explanation"])
NuCycle = NuCycle.reindex(columns=["Occupation", "BFF_Team", "Gender", "Nationality", "Human wellbeing", "Community development", "Environmental regeneration", "Balanced?", "Ingenious technology", "Globally scalable", "Out-of-the-box", "Explanation"])
IDEP = IDEP.reindex(columns=["Occupation", "BFF_Team", "Gender", "Nationality", "Human wellbeing", "Community development", "Environmental regeneration", "Balanced?", "Ingenious technology", "Globally scalable", "Out-of-the-box", "Explanation"])
Hydropods = Hydropods.reindex(columns=["Occupation", "BFF_Team", "Gender", "Nationality", "Human wellbeing", "Community development", "Environmental regeneration", "Balanced?", "Ingenious technology", "Globally scalable", "Out-of-the-box", "Explanation"])
Prakash = Prakash.reindex(columns=["Occupation", "BFF_Team", "Gender", "Nationality", "Human wellbeing", "Community development", "Environmental regeneration", "Balanced?", "Ingenious technology", "Globally scalable", "Out-of-the-box", "Explanation"])
PP = PP.reindex(columns=["Occupation", "BFF_Team", "Gender", "Nationality", "Human wellbeing", "Community development", "Environmental regeneration", "Balanced?", "Ingenious technology", "Globally scalable", "Out-of-the-box", "Explanation"])
PE = PE.reindex(columns=["Occupation", "BFF_Team", "Gender", "Nationality", "Human wellbeing", "Community development", "Environmental regeneration", "Balanced?", "Ingenious technology", "Globally scalable", "Out-of-the-box", "Explanation"])
Printridi = Printridi.reindex(columns=["Occupation", "BFF_Team", "Gender", "Nationality", "Human wellbeing", "Community development", "Environmental regeneration", "Balanced?", "Ingenious technology", "Globally scalable", "Out-of-the-box", "Explanation"])

# Change ints to floats
Kopernik = Kopernik.astype({'Human wellbeing':'float','Community development':'float','Environmental regeneration':'float','Ingenious technology':'float','Globally scalable':'float','Out-of-the-box':'float'})
BambooU = BambooU.astype({'Human wellbeing':'float','Community development':'float','Environmental regeneration':'float','Ingenious technology':'float','Globally scalable':'float','Out-of-the-box':'float'})
NuCycle = NuCycle.astype({'Human wellbeing':'float','Community development':'float','Environmental regeneration':'float','Ingenious technology':'float','Globally scalable':'float','Out-of-the-box':'float'})
IDEP = IDEP.astype({'Human wellbeing':'float','Community development':'float','Environmental regeneration':'float','Ingenious technology':'float','Globally scalable':'float','Out-of-the-box':'float'})
Hydropods = Hydropods.astype({'Human wellbeing':'float','Community development':'float','Environmental regeneration':'float','Ingenious technology':'float','Globally scalable':'float','Out-of-the-box':'float'})
Prakash = Prakash.astype({'Human wellbeing':'float','Community development':'float','Environmental regeneration':'float','Ingenious technology':'float','Globally scalable':'float','Out-of-the-box':'float'})
PP = PP.astype({'Human wellbeing':'float','Community development':'float','Environmental regeneration':'float','Ingenious technology':'float','Globally scalable':'float','Out-of-the-box':'float'})
PE = PE.astype({'Human wellbeing':'float','Community development':'float','Environmental regeneration':'float','Ingenious technology':'float','Globally scalable':'float','Out-of-the-box':'float'})
Printridi = Printridi.astype({'Human wellbeing':'float','Community development':'float','Environmental regeneration':'float','Ingenious technology':'float','Globally scalable':'float','Out-of-the-box':'float'})

# %%
Kopernik['Nationality'] = Kopernik['Nationality'].str.lower()
BambooU['Nationality'] = BambooU['Nationality'].str.lower()
NuCycle['Nationality'] = NuCycle['Nationality'].str.lower()
IDEP['Nationality'] = IDEP['Nationality'].str.lower()
Hydropods['Nationality'] = Hydropods['Nationality'].str.lower()
Prakash['Nationality'] = Prakash['Nationality'].str.lower()
PP['Nationality'] = PP['Nationality'].str.lower()
PE['Nationality'] = PE['Nationality'].str.lower()
Printridi['Nationality'] = Printridi['Nationality'].str.lower()

# Define local population
Kopernik['Nationality'] = Kopernik['Nationality'].replace(['indonesian', 'indonesia', 'indo', 'bali', 'balinese'],'Local')
BambooU['Nationality'] = BambooU['Nationality'].replace(['indonesian', 'indonesia', 'indo', 'bali', 'balinese'],'Local')
NuCycle['Nationality'] = NuCycle['Nationality'].replace(['indonesian', 'indonesia', 'indo', 'bali', 'balinese'],'Local')
IDEP['Nationality'] = IDEP['Nationality'].replace(['indonesian', 'indonesia', 'indo', 'bali', 'balinese'],'Local')
Hydropods['Nationality'] = Hydropods['Nationality'].replace(['indonesian', 'indonesia', 'indo', 'bali', 'balinese'],'Local')
Prakash['Nationality'] = Prakash['Nationality'].replace(['indonesian', 'indonesia', 'indo', 'bali', 'balinese'],'Local')
PP['Nationality'] = PP['Nationality'].replace(['indonesian', 'indonesia', 'indo', 'bali', 'balinese'],'Local')
PE['Nationality'] = PE['Nationality'].replace(['indonesian', 'indonesia', 'indo', 'bali', 'balinese'],'Local')
Printridi['Nationality'] = Printridi['Nationality'].replace(['indonesian', 'indonesia', 'indo', 'bali', 'balinese'],'Local')

# Define global population
Kopernik['Nationality'] = np.where((Kopernik['Nationality'] == 'Local'), Kopernik['Nationality'], 'Global')
BambooU['Nationality'] = np.where((BambooU['Nationality'] == 'Local'), BambooU['Nationality'], 'Global')
NuCycle['Nationality'] = np.where((NuCycle['Nationality'] == 'Local'), NuCycle['Nationality'], 'Global')
IDEP['Nationality'] = np.where((IDEP['Nationality'] == 'Local'), IDEP['Nationality'], 'Global')
Hydropods['Nationality'] = np.where((Hydropods['Nationality'] == 'Local'), Hydropods['Nationality'], 'Global')
Prakash['Nationality'] = np.where((Prakash['Nationality'] == 'Local'), Prakash['Nationality'], 'Global')
PP['Nationality'] = np.where((PP['Nationality'] == 'Local'), PP['Nationality'], 'Global')
PE['Nationality'] = np.where((PE['Nationality'] == 'Local'), PE['Nationality'], 'Global')
Printridi['Nationality'] = np.where((Printridi['Nationality'] == 'Local'), Printridi['Nationality'], 'Global')

# Define professionals
Kopernik['Occupation'] = Kopernik['Occupation'].replace(['Business owner/Entrepreneur', 'Makers/Fabricators', 'Policy makers', 'Educators/Intructor/Academics'],'Professional')
BambooU['Occupation'] = BambooU['Occupation'].replace(['Business owner/Entrepreneur', 'Makers/Fabricators', 'Policy makers', 'Educators/Intructor/Academics'],'Professional')
NuCycle['Occupation'] = NuCycle['Occupation'].replace(['Business owner/Entrepreneur', 'Makers/Fabricators', 'Policy makers', 'Educators/Intructor/Academics'],'Professional')
IDEP['Occupation'] = IDEP['Occupation'].replace(['Business owner/Entrepreneur', 'Makers/Fabricators', 'Policy makers', 'Educators/Intructor/Academics'],'Professional')
Hydropods['Occupation'] = Hydropods['Occupation'].replace(['Business owner/Entrepreneur', 'Makers/Fabricators', 'Policy makers', 'Educators/Intructor/Academics'],'Professional')
Prakash['Occupation'] = Prakash['Occupation'].replace(['Business owner/Entrepreneur', 'Makers/Fabricators', 'Policy makers', 'Educators/Intructor/Academics'],'Professional')
PP['Occupation'] = PP['Occupation'].replace(['Business owner/Entrepreneur', 'Makers/Fabricators', 'Policy makers', 'Educators/Intructor/Academics'],'Professional')
PE['Occupation'] = PE['Occupation'].replace(['Business owner/Entrepreneur', 'Makers/Fabricators', 'Policy makers', 'Educators/Intructor/Academics'],'Professional')
Printridi['Occupation'] = Printridi['Occupation'].replace(['Business owner/Entrepreneur', 'Makers/Fabricators', 'Policy makers', 'Educators/Intructor/Academics'],'Professional')

#Define enthusiasts
Kopernik['Occupation'] = Kopernik['Occupation'].replace(['Local enthusiast', 'Student interested in digital fabrication'],'Enthusiast')
BambooU['Occupation'] = BambooU['Occupation'].replace(['Local enthusiast', 'Student interested in digital fabrication'],'Enthusiast')
NuCycle['Occupation'] = NuCycle['Occupation'].replace(['Local enthusiast', 'Student interested in digital fabrication'],'Enthusiast')
IDEP['Occupation'] = IDEP['Occupation'].replace(['Local enthusiast', 'Student interested in digital fabrication'],'Enthusiast')
Hydropods['Occupation'] = Hydropods['Occupation'].replace(['Local enthusiast', 'Student interested in digital fabrication'],'Enthusiast')
Prakash['Occupation'] = Prakash['Occupation'].replace(['Local enthusiast', 'Student interested in digital fabrication'],'Enthusiast')
PP['Occupation'] = PP['Occupation'].replace(['Local enthusiast', 'Student interested in digital fabrication'],'Enthusiast')
PE['Occupation'] = PE['Occupation'].replace(['Local enthusiast', 'Student interested in digital fabrication'],'Enthusiast')
Printridi['Occupation'] = Printridi['Occupation'].replace(['Local enthusiast', 'Student interested in digital fabrication'],'Enthusiast')

# Define experts
Kopernik['Occupation'] = np.where((Kopernik['BFF_Team'] != 'Yes'), Kopernik['Occupation'], 'Expert')
BambooU['Occupation'] = np.where((BambooU['BFF_Team'] != 'Yes'), BambooU['Occupation'], 'Expert')
NuCycle['Occupation'] = np.where((NuCycle['BFF_Team'] != 'Yes'), NuCycle['Occupation'], 'Expert')
IDEP['Occupation'] = np.where((IDEP['BFF_Team'] != 'Yes'), IDEP['Occupation'], 'Expert')
Hydropods['Occupation'] = np.where((Hydropods['BFF_Team'] != 'Yes'), Hydropods['Occupation'], 'Expert')
Prakash['Occupation'] = np.where((Prakash['BFF_Team'] != 'Yes'), Prakash['Occupation'], 'Expert')
PP['Occupation'] = np.where((PP['BFF_Team'] != 'Yes'), PP['Occupation'], 'Expert')
PE['Occupation'] = np.where((PE['BFF_Team'] != 'Yes'), PE['Occupation'], 'Expert')
Printridi['Occupation'] = np.where((Printridi['BFF_Team'] != 'Yes'), Printridi['Occupation'], 'Expert')

# Define roles
Kopernik["Role"] = Kopernik['Nationality'].astype(str) +" "+ Kopernik["Occupation"]
BambooU["Role"] = BambooU['Nationality'].astype(str) +" "+ BambooU["Occupation"]
NuCycle["Role"] = NuCycle['Nationality'].astype(str) +" "+ NuCycle["Occupation"]
IDEP["Role"] = IDEP['Nationality'].astype(str) +" "+ IDEP["Occupation"]
Hydropods["Role"] = Hydropods['Nationality'].astype(str) +" "+ Hydropods["Occupation"]
Prakash["Role"] = Prakash['Nationality'].astype(str) +" "+ Prakash["Occupation"]
PP["Role"] = PP['Nationality'].astype(str) +" "+ PP["Occupation"]
PE["Role"] = PE['Nationality'].astype(str) +" "+ PE["Occupation"]
Printridi["Role"] = Printridi['Nationality'].astype(str) +" "+ Printridi["Occupation"]

# %%
# Average balance score
Kopernik['Balance'] = (Kopernik['Human wellbeing'] + Kopernik['Community development'] + Kopernik['Environmental regeneration'])/3
BambooU['Balance'] = (BambooU['Human wellbeing'] + BambooU['Community development'] + BambooU['Environmental regeneration'])/3
NuCycle['Balance'] = (NuCycle['Human wellbeing'] + NuCycle['Community development'] + NuCycle['Environmental regeneration'])/3
IDEP['Balance'] = (IDEP['Human wellbeing'] + IDEP['Community development'] + IDEP['Environmental regeneration'])/3
Hydropods['Balance'] = (Hydropods['Human wellbeing'] + Hydropods['Community development'] + Hydropods['Environmental regeneration'])/3
Prakash['Balance'] = (Prakash['Human wellbeing'] + Prakash['Community development'] + Prakash['Environmental regeneration'])/3
PP['Balance'] = (PP['Human wellbeing'] + PP['Community development'] + PP['Environmental regeneration'])/3
PE['Balance'] = (PE['Human wellbeing'] + PE['Community development'] + PE['Environmental regeneration'])/3
Printridi['Balance'] = (Printridi['Human wellbeing'] + Printridi['Community development'] + Printridi['Environmental regeneration'])/3


# Average innovation score
Kopernik['Innovation'] = (Kopernik['Ingenious technology'] + Kopernik['Globally scalable'] + Kopernik['Out-of-the-box'])/3
BambooU['Innovation'] = (BambooU['Ingenious technology'] + BambooU['Globally scalable'] + BambooU['Out-of-the-box'])/3
NuCycle['Innovation'] = (NuCycle['Ingenious technology'] + NuCycle['Globally scalable'] + NuCycle['Out-of-the-box'])/3
IDEP['Innovation'] = (IDEP['Ingenious technology'] + IDEP['Globally scalable'] + IDEP['Out-of-the-box'])/3
Hydropods['Innovation'] = (Hydropods['Ingenious technology'] + Hydropods['Globally scalable'] + Hydropods['Out-of-the-box'])/3
Prakash['Innovation'] = (Prakash['Ingenious technology'] + Prakash['Globally scalable'] + Prakash['Out-of-the-box'])/3
PP['Innovation'] = (PP['Ingenious technology'] + PP['Globally scalable'] + PP['Out-of-the-box'])/3
PE['Innovation'] = (PE['Ingenious technology'] + PE['Globally scalable'] + PE['Out-of-the-box'])/3
Printridi['Innovation'] = (Printridi['Ingenious technology'] + Printridi['Globally scalable'] + Printridi['Out-of-the-box'])/3

# %%
# Weighting local votes
Kopernik['Balance'] = np.where((Kopernik['Role'] == 'Local Enthusiast') & (Kopernik['Balance'] >= 4), Kopernik['Balance'] * 1.125, Kopernik['Balance'])
Kopernik['Balance'] = np.where((Kopernik['Role'] == 'Local Enthusiast') & (Kopernik['Balance'] <= 3), Kopernik['Balance'] * 0.875, Kopernik['Balance'])

BambooU['Balance'] = np.where((BambooU['Role'] == 'Local Enthusiast') & (BambooU['Balance'] >= 4), BambooU['Balance'] * 1.125, BambooU['Balance'])
BambooU['Balance'] = np.where((BambooU['Role'] == 'Local Enthusiast') & (BambooU['Balance'] <= 3), BambooU['Balance'] * 0.875, BambooU['Balance'])

NuCycle['Balance'] = np.where((NuCycle['Role'] == 'Local Enthusiast') & (NuCycle['Balance'] >= 4), NuCycle['Balance'] * 1.125, NuCycle['Balance'])
NuCycle['Balance'] = np.where((NuCycle['Role'] == 'Local Enthusiast') & (NuCycle['Balance'] <= 3), NuCycle['Balance'] * 0.875, NuCycle['Balance'])

IDEP['Balance'] = np.where((IDEP['Role'] == 'Local Enthusiast') & (IDEP['Balance'] >= 4), IDEP['Balance'] * 1.125, IDEP['Balance'])
IDEP['Balance'] = np.where((IDEP['Role'] == 'Local Enthusiast') & (IDEP['Balance'] <= 3), IDEP['Balance'] * 0.875, IDEP['Balance'])

Hydropods['Balance'] = np.where((Hydropods['Role'] == 'Local Enthusiast') & (Hydropods['Balance'] >= 4), Hydropods['Balance'] * 1.125, Hydropods['Balance'])
Hydropods['Balance'] = np.where((Hydropods['Role'] == 'Local Enthusiast') & (Hydropods['Balance'] <= 3), Hydropods['Balance'] * 0.875, Hydropods['Balance'])

Prakash['Balance'] = np.where((Prakash['Role'] == 'Local Enthusiast') & (Prakash['Balance'] >= 4), Prakash['Balance'] * 1.125, Prakash['Balance'])
Prakash['Balance'] = np.where((Prakash['Role'] == 'Local Enthusiast') & (Prakash['Balance'] <= 3), Prakash['Balance'] * 0.875, Prakash['Balance'])

PP['Balance'] = np.where((PP['Role'] == 'Local Enthusiast') & (PP['Balance'] >= 4), PP['Balance'] * 1.125, PP['Balance'])
PP['Balance'] = np.where((PP['Role'] == 'Local Enthusiast') & (PP['Balance'] <= 3), PP['Balance'] * 0.875, PP['Balance'])

PE['Balance'] = np.where((PE['Role'] == 'Local Enthusiast') & (PE['Balance'] >= 4), PE['Balance'] * 1.125, PE['Balance'])
PE['Balance'] = np.where((PE['Role'] == 'Local Enthusiast') & (PE['Balance'] <= 3), PE['Balance'] * 0.875, PE['Balance'])

Printridi['Balance'] = np.where((Printridi['Role'] == 'Local Enthusiast') & (Printridi['Balance'] >= 4), Printridi['Balance'] * 1.125, Printridi['Balance'])
Printridi['Balance'] = np.where((Printridi['Role'] == 'Local Enthusiast') & (Printridi['Balance'] <= 3), Printridi['Balance'] * 0.875, Printridi['Balance'])

Kopernik['Balance'] = np.where((Kopernik['Role'] == 'Local Professional') & (Kopernik['Balance'] >= 4), Kopernik['Balance'] * 1.25, Kopernik['Balance'])
Kopernik['Balance'] = np.where((Kopernik['Role'] == 'Local Professional') & (Kopernik['Balance'] <= 3), Kopernik['Balance'] * 0.75, Kopernik['Balance'])

BambooU['Balance'] = np.where((BambooU['Role'] == 'Local Professional') & (BambooU['Balance'] >= 4), BambooU['Balance'] * 1.25, BambooU['Balance'])
BambooU['Balance'] = np.where((BambooU['Role'] == 'Local Professional') & (BambooU['Balance'] <= 3), BambooU['Balance'] * 0.75, BambooU['Balance'])

NuCycle['Balance'] = np.where((NuCycle['Role'] == 'Local Professional') & (NuCycle['Balance'] >= 4), NuCycle['Balance'] * 1.25, NuCycle['Balance'])
NuCycle['Balance'] = np.where((NuCycle['Role'] == 'Local Professional') & (NuCycle['Balance'] <= 3), NuCycle['Balance'] * 0.75, NuCycle['Balance'])

IDEP['Balance'] = np.where((IDEP['Role'] == 'Local Professional') & (IDEP['Balance'] >= 4), IDEP['Balance'] * 1.25, IDEP['Balance'])
IDEP['Balance'] = np.where((IDEP['Role'] == 'Local Professional') & (IDEP['Balance'] <= 3), IDEP['Balance'] * 0.75, IDEP['Balance'])

Hydropods['Balance'] = np.where((Hydropods['Role'] == 'Local Professional') & (Hydropods['Balance'] >= 4), Hydropods['Balance'] * 1.25, Hydropods['Balance'])
Hydropods['Balance'] = np.where((Hydropods['Role'] == 'Local Professional') & (Hydropods['Balance'] <= 3), Hydropods['Balance'] * 0.75, Hydropods['Balance'])

Prakash['Balance'] = np.where((Prakash['Role'] == 'Local Professional') & (Prakash['Balance'] >= 4), Prakash['Balance'] * 1.25, Prakash['Balance'])
Prakash['Balance'] = np.where((Prakash['Role'] == 'Local Professional') & (Prakash['Balance'] <= 3), Prakash['Balance'] * 0.75, Prakash['Balance'])

PP['Balance'] = np.where((PP['Role'] == 'Local Professional') & (PP['Balance'] >= 4), PP['Balance'] * 1.25, PP['Balance'])
PP['Balance'] = np.where((PP['Role'] == 'Local Professional') & (PP['Balance'] <= 3), PP['Balance'] * 0.75, PP['Balance'])

PE['Balance'] = np.where((PE['Role'] == 'Local Professional') & (PE['Balance'] >= 4), PE['Balance'] * 1.25, PE['Balance'])
PE['Balance'] = np.where((PE['Role'] == 'Local Professional') & (PE['Balance'] <= 3), PE['Balance'] * 0.75, PE['Balance'])

Printridi['Balance'] = np.where((Printridi['Role'] == 'Local Professional') & (Printridi['Balance'] >= 4), Printridi['Balance'] * 1.25, Printridi['Balance'])
Printridi['Balance'] = np.where((Printridi['Role'] == 'Local Professional') & (Printridi['Balance'] <= 3), Printridi['Balance'] * 0.75, Printridi['Balance'])

Kopernik['Balance'] = np.where((Kopernik['Role'] == 'Local Expert') & (Kopernik['Balance'] >= 4), Kopernik['Balance'] * 1.5, Kopernik['Balance'])
Kopernik['Balance'] = np.where((Kopernik['Role'] == 'Local Expert') & (Kopernik['Balance'] <= 3), Kopernik['Balance'] * 0.5, Kopernik['Balance'])

BambooU['Balance'] = np.where((BambooU['Role'] == 'Local Expert') & (BambooU['Balance'] >= 4), BambooU['Balance'] * 1.5, BambooU['Balance'])
BambooU['Balance'] = np.where((BambooU['Role'] == 'Local Expert') & (BambooU['Balance'] <= 3), BambooU['Balance'] * 0.5, BambooU['Balance'])

NuCycle['Balance'] = np.where((NuCycle['Role'] == 'Local Expert') & (NuCycle['Balance'] >= 4), NuCycle['Balance'] * 1.5, NuCycle['Balance'])
NuCycle['Balance'] = np.where((NuCycle['Role'] == 'Local Expert') & (NuCycle['Balance'] <= 3), NuCycle['Balance'] * 0.5, NuCycle['Balance'])

IDEP['Balance'] = np.where((IDEP['Role'] == 'Local Expert') & (IDEP['Balance'] >= 4), IDEP['Balance'] * 1.5, IDEP['Balance'])
IDEP['Balance'] = np.where((IDEP['Role'] == 'Local Expert') & (IDEP['Balance'] <= 3), IDEP['Balance'] * 0.5, IDEP['Balance'])

Hydropods['Balance'] = np.where((Hydropods['Role'] == 'Local Expert') & (Hydropods['Balance'] >= 4), Hydropods['Balance'] * 1.5, Hydropods['Balance'])
Hydropods['Balance'] = np.where((Hydropods['Role'] == 'Local Expert') & (Hydropods['Balance'] <= 3), Hydropods['Balance'] * 0.5, Hydropods['Balance'])

Prakash['Balance'] = np.where((Prakash['Role'] == 'Local Expert') & (Prakash['Balance'] >= 4), Prakash['Balance'] * 1.5, Prakash['Balance'])
Prakash['Balance'] = np.where((Prakash['Role'] == 'Local Expert') & (Prakash['Balance'] <= 3), Prakash['Balance'] * 0.5, Prakash['Balance'])

PP['Balance'] = np.where((PP['Role'] == 'Local Expert') & (PP['Balance'] >= 4), PP['Balance'] * 1.5, PP['Balance'])
PP['Balance'] = np.where((PP['Role'] == 'Local Expert') & (PP['Balance'] <= 3), PP['Balance'] * 0.5, PP['Balance'])

PE['Balance'] = np.where((PE['Role'] == 'Local Expert') & (PE['Balance'] >= 4), PE['Balance'] * 1.5, PE['Balance'])
PE['Balance'] = np.where((PE['Role'] == 'Local Expert') & (PE['Balance'] <= 3), PE['Balance'] * 0.5, PE['Balance'])

Printridi['Balance'] = np.where((Printridi['Role'] == 'Local Expert') & (Printridi['Balance'] >= 4), Printridi['Balance'] * 1.5, Printridi['Balance'])
Printridi['Balance'] = np.where((Printridi['Role'] == 'Local Expert') & (Printridi['Balance'] <= 3), Printridi['Balance'] * 0.5, Printridi['Balance'])

Kopernik['Innovation'] = np.where((Kopernik['Role'] == 'Local Expert') & (Kopernik['Innovation'] >= 4), Kopernik['Innovation'] * 1.5, Kopernik['Innovation'])
Kopernik['Innovation'] = np.where((Kopernik['Role'] == 'Local Expert') & (Kopernik['Innovation'] <= 3), Kopernik['Innovation'] * 0.5, Kopernik['Innovation'])

BambooU['Innovation'] = np.where((BambooU['Role'] == 'Local Expert') & (BambooU['Innovation'] >= 4), BambooU['Innovation'] * 1.5, BambooU['Innovation'])
BambooU['Innovation'] = np.where((BambooU['Role'] == 'Local Expert') & (BambooU['Innovation'] <= 3), BambooU['Innovation'] * 0.5, BambooU['Innovation'])

NuCycle['Innovation'] = np.where((NuCycle['Role'] == 'Local Expert') & (NuCycle['Innovation'] >= 4), NuCycle['Innovation'] * 1.5, NuCycle['Innovation'])
NuCycle['Innovation'] = np.where((NuCycle['Role'] == 'Local Expert') & (NuCycle['Innovation'] <= 3), NuCycle['Innovation'] * 0.5, NuCycle['Innovation'])

IDEP['Innovation'] = np.where((IDEP['Role'] == 'Local Expert') & (IDEP['Innovation'] >= 4), IDEP['Innovation'] * 1.5, IDEP['Innovation'])
IDEP['Innovation'] = np.where((IDEP['Role'] == 'Local Expert') & (IDEP['Innovation'] <= 3), IDEP['Innovation'] * 0.5, IDEP['Innovation'])

Hydropods['Innovation'] = np.where((Hydropods['Role'] == 'Local Expert') & (Hydropods['Innovation'] >= 4), Hydropods['Innovation'] * 1.5, Hydropods['Innovation'])
Hydropods['Innovation'] = np.where((Hydropods['Role'] == 'Local Expert') & (Hydropods['Innovation'] <= 3), Hydropods['Innovation'] * 0.5, Hydropods['Innovation'])

Prakash['Innovation'] = np.where((Prakash['Role'] == 'Local Expert') & (Prakash['Innovation'] >= 4), Prakash['Innovation'] * 1.5, Prakash['Innovation'])
Prakash['Innovation'] = np.where((Prakash['Role'] == 'Local Expert') & (Prakash['Innovation'] <= 3), Prakash['Innovation'] * 0.5, Prakash['Innovation'])

PP['Innovation'] = np.where((PP['Role'] == 'Local Expert') & (PP['Innovation'] >= 4), PP['Innovation'] * 1.5, PP['Innovation'])
PP['Innovation'] = np.where((PP['Role'] == 'Local Expert') & (PP['Innovation'] <= 3), PP['Innovation'] * 0.5, PP['Innovation'])

PE['Innovation'] = np.where((PE['Role'] == 'Local Expert') & (PE['Innovation'] >= 4), PE['Innovation'] * 1.5, PE['Innovation'])
PE['Innovation'] = np.where((PE['Role'] == 'Local Expert') & (PE['Innovation'] <= 3), PE['Innovation'] * 0.5, PE['Innovation'])

Printridi['Innovation'] = np.where((Printridi['Role'] == 'Local Expert') & (Printridi['Innovation'] >= 4), Printridi['Innovation'] * 1.5, Printridi['Innovation'])
Printridi['Innovation'] = np.where((Printridi['Role'] == 'Local Expert') & (Printridi['Innovation'] <= 3), Printridi['Innovation'] * 0.5, Printridi['Innovation'])

# Weighting global votes
Kopernik['Innovation'] = np.where((Kopernik['Role'] == 'Global Professional') & (Kopernik['Innovation'] >= 4), Kopernik['Innovation'] * 1.25, Kopernik['Innovation'])
Kopernik['Innovation'] = np.where((Kopernik['Role'] == 'Global Professional') & (Kopernik['Innovation'] <= 3), Kopernik['Innovation'] * 0.75, Kopernik['Innovation'])

BambooU['Innovation'] = np.where((BambooU['Role'] == 'Global Professional') & (BambooU['Innovation'] >= 4), BambooU['Innovation'] * 1.25, BambooU['Innovation'])
BambooU['Innovation'] = np.where((BambooU['Role'] == 'Global Professional') & (BambooU['Innovation'] <= 3), BambooU['Innovation'] * 0.75, BambooU['Innovation'])

NuCycle['Innovation'] = np.where((NuCycle['Role'] == 'Global Professional') & (NuCycle['Innovation'] >= 4), NuCycle['Innovation'] * 1.25, NuCycle['Innovation'])
NuCycle['Innovation'] = np.where((NuCycle['Role'] == 'Global Professional') & (NuCycle['Innovation'] <= 3), NuCycle['Innovation'] * 0.75, NuCycle['Innovation'])

IDEP['Innovation'] = np.where((IDEP['Role'] == 'Global Professional') & (IDEP['Innovation'] >= 4), IDEP['Innovation'] * 1.25, IDEP['Innovation'])
IDEP['Innovation'] = np.where((IDEP['Role'] == 'Global Professional') & (IDEP['Innovation'] <= 3), IDEP['Innovation'] * 0.75, IDEP['Innovation'])

Hydropods['Innovation'] = np.where((Hydropods['Role'] == 'Global Professional') & (Hydropods['Innovation'] >= 4), Hydropods['Innovation'] * 1.25, Hydropods['Innovation'])
Hydropods['Innovation'] = np.where((Hydropods['Role'] == 'Global Professional') & (Hydropods['Innovation'] <= 3), Hydropods['Innovation'] * 0.75, Hydropods['Innovation'])

Prakash['Innovation'] = np.where((Prakash['Role'] == 'Global Professional') & (Prakash['Innovation'] >= 4), Prakash['Innovation'] * 1.25, Prakash['Innovation'])
Prakash['Innovation'] = np.where((Prakash['Role'] == 'Global Professional') & (Prakash['Innovation'] <= 3), Prakash['Innovation'] * 0.75, Prakash['Innovation'])

PP['Innovation'] = np.where((PP['Role'] == 'Global Professional') & (PP['Innovation'] >= 4), PP['Innovation'] * 1.25, PP['Innovation'])
PP['Innovation'] = np.where((PP['Role'] == 'Global Professional') & (PP['Innovation'] <= 3), PP['Innovation'] * 0.75, PP['Innovation'])

PE['Innovation'] = np.where((PE['Role'] == 'Global Professional') & (PE['Innovation'] >= 4), PE['Innovation'] * 1.25, PE['Innovation'])
PE['Innovation'] = np.where((PE['Role'] == 'Global Professional') & (PE['Innovation'] <= 3), PE['Innovation'] * 0.75, PE['Innovation'])

Printridi['Innovation'] = np.where((Printridi['Role'] == 'Global Professional') & (Printridi['Innovation'] >= 4), Printridi['Innovation'] * 1.25, Printridi['Innovation'])
Printridi['Innovation'] = np.where((Printridi['Role'] == 'Global Professional') & (Printridi['Innovation'] <= 3), Printridi['Innovation'] * 0.75, Printridi['Innovation'])

Kopernik['Innovation'] = np.where((Kopernik['Role'] == 'Global Expert') & (Kopernik['Innovation'] >= 4), Kopernik['Innovation'] * 1.5, Kopernik['Innovation'])
Kopernik['Innovation'] = np.where((Kopernik['Role'] == 'Global Expert') & (Kopernik['Innovation'] <= 3), Kopernik['Innovation'] * 0.5, Kopernik['Innovation'])
Kopernik['Balance'] = np.where((Kopernik['Role'] == 'Global Expert') & (Kopernik['Balance'] >= 4), Kopernik['Balance'] * 1.25, Kopernik['Balance'])
Kopernik['Balance'] = np.where((Kopernik['Role'] == 'Global Expert') & (Kopernik['Balance'] <= 3), Kopernik['Balance'] * 0.75, Kopernik['Balance'])

BambooU['Innovation'] = np.where((BambooU['Role'] == 'Global Expert') & (BambooU['Innovation'] >= 4), BambooU['Innovation'] * 1.5, BambooU['Innovation'])
BambooU['Innovation'] = np.where((BambooU['Role'] == 'Global Expert') & (BambooU['Innovation'] <= 3), BambooU['Innovation'] * 0.5, BambooU['Innovation'])
BambooU['Balance'] = np.where((BambooU['Role'] == 'Global Expert') & (BambooU['Balance'] >= 4), BambooU['Balance'] * 1.25, BambooU['Balance'])
BambooU['Balance'] = np.where((BambooU['Role'] == 'Global Expert') & (BambooU['Balance'] <= 3), BambooU['Balance'] * 0.75, BambooU['Balance'])

NuCycle['Innovation'] = np.where((NuCycle['Role'] == 'Global Expert') & (NuCycle['Innovation'] >= 4), NuCycle['Innovation'] * 1.5, NuCycle['Innovation'])
NuCycle['Innovation'] = np.where((NuCycle['Role'] == 'Global Expert') & (NuCycle['Innovation'] <= 3), NuCycle['Innovation'] * 0.5, NuCycle['Innovation'])
NuCycle['Balance'] = np.where((NuCycle['Role'] == 'Global Expert') & (NuCycle['Balance'] >= 4), NuCycle['Balance'] * 1.25, NuCycle['Balance'])
NuCycle['Balance'] = np.where((NuCycle['Role'] == 'Global Expert') & (NuCycle['Balance'] <= 3), NuCycle['Balance'] * 0.75, NuCycle['Balance'])

IDEP['Innovation'] = np.where((IDEP['Role'] == 'Global Expert') & (IDEP['Innovation'] >= 4), IDEP['Innovation'] * 1.5, IDEP['Innovation'])
IDEP['Innovation'] = np.where((IDEP['Role'] == 'Global Expert') & (IDEP['Innovation'] <= 3), IDEP['Innovation'] * 0.5, IDEP['Innovation'])
IDEP['Balance'] = np.where((IDEP['Role'] == 'Global Expert') & (IDEP['Balance'] >= 4), IDEP['Balance'] * 1.25, IDEP['Balance'])
IDEP['Balance'] = np.where((IDEP['Role'] == 'Global Expert') & (IDEP['Balance'] <= 3), IDEP['Balance'] * 0.75, IDEP['Balance'])

Hydropods['Innovation'] = np.where((Hydropods['Role'] == 'Global Expert') & (Hydropods['Innovation'] >= 4), Hydropods['Innovation'] * 1.5, Hydropods['Innovation'])
Hydropods['Innovation'] = np.where((Hydropods['Role'] == 'Global Expert') & (Hydropods['Innovation'] <= 3), Hydropods['Innovation'] * 0.5, Hydropods['Innovation'])
Hydropods['Balance'] = np.where((Hydropods['Role'] == 'Global Expert') & (Hydropods['Balance'] >= 4), Hydropods['Balance'] * 1.25, Hydropods['Balance'])
Hydropods['Balance'] = np.where((Hydropods['Role'] == 'Global Expert') & (Hydropods['Balance'] <= 3), Hydropods['Balance'] * 0.75, Hydropods['Balance'])

Prakash['Innovation'] = np.where((Prakash['Role'] == 'Global Expert') & (Prakash['Innovation'] >= 4), Prakash['Innovation'] * 1.5, Prakash['Innovation'])
Prakash['Innovation'] = np.where((Prakash['Role'] == 'Global Expert') & (Prakash['Innovation'] <= 3), Prakash['Innovation'] * 0.5, Prakash['Innovation'])
Prakash['Balance'] = np.where((Prakash['Role'] == 'Global Expert') & (Prakash['Balance'] >= 4), Prakash['Balance'] * 1.25, Prakash['Balance'])
Prakash['Balance'] = np.where((Prakash['Role'] == 'Global Expert') & (Prakash['Balance'] <= 3), Prakash['Balance'] * 0.75, Prakash['Balance'])

PP['Innovation'] = np.where((PP['Role'] == 'Global Expert') & (PP['Innovation'] >= 4), PP['Innovation'] * 1.5, PP['Innovation'])
PP['Innovation'] = np.where((PP['Role'] == 'Global Expert') & (PP['Innovation'] <= 3), PP['Innovation'] * 0.5, PP['Innovation'])
PP['Balance'] = np.where((PP['Role'] == 'Global Expert') & (PP['Balance'] >= 4), PP['Balance'] * 1.25, PP['Balance'])
PP['Balance'] = np.where((PP['Role'] == 'Global Expert') & (PP['Balance'] <= 3), PP['Balance'] * 0.75, PP['Balance'])

PE['Innovation'] = np.where((PE['Role'] == 'Global Expert') & (PE['Innovation'] >= 4), PE['Innovation'] * 1.5, PE['Innovation'])
PE['Innovation'] = np.where((PE['Role'] == 'Global Expert') & (PE['Innovation'] <= 3), PE['Innovation'] * 0.5, PE['Innovation'])
PE['Balance'] = np.where((PE['Role'] == 'Global Expert') & (PE['Balance'] >= 4), PE['Balance'] * 1.25, PE['Balance'])
PE['Balance'] = np.where((PE['Role'] == 'Global Expert') & (PE['Balance'] <= 3), PE['Balance'] * 0.75, PE['Balance'])

Printridi['Innovation'] = np.where((Printridi['Role'] == 'Global Expert') & (Printridi['Innovation'] >= 4), Printridi['Innovation'] * 1.5, Printridi['Innovation'])
Printridi['Innovation'] = np.where((Printridi['Role'] == 'Global Expert') & (Printridi['Innovation'] <= 3), Printridi['Innovation'] * 0.5, Printridi['Innovation'])
Printridi['Balance'] = np.where((Printridi['Role'] == 'Global Expert') & (Printridi['Balance'] >= 4), Printridi['Balance'] * 1.25, Printridi['Balance'])
Printridi['Balance'] = np.where((Printridi['Role'] == 'Global Expert') & (Printridi['Balance'] <= 3), Printridi['Balance'] * 0.75, Printridi['Balance'])

# %%
#Avg = Kopernik[['Balance','Innovation']].mean()
ScoreKopernik = pd.DataFrame(Kopernik[['Balance','Innovation']].mean())
ScoreKopernik.loc['Total']= ScoreKopernik.mean()
ScoreKopernik.columns = ['Kopernik']

ScoreBambooU = pd.DataFrame(BambooU[['Balance','Innovation']].mean())
ScoreBambooU.loc['Total']= ScoreBambooU.mean()
ScoreBambooU.columns = ['BambooU']

ScoreNuCycle = pd.DataFrame(NuCycle[['Balance','Innovation']].mean())
ScoreNuCycle.loc['Total']= ScoreNuCycle.mean()
ScoreNuCycle.columns = ['NuCycle']

ScoreIDEP = pd.DataFrame(IDEP[['Balance','Innovation']].mean())
ScoreIDEP.loc['Total']= ScoreIDEP.mean()
ScoreIDEP.columns = ['IDEP']

ScoreHydropods = pd.DataFrame(Hydropods[['Balance','Innovation']].mean())
ScoreHydropods.loc['Total']= ScoreHydropods.mean()
ScoreHydropods.columns = ['Hydropods']

ScorePrakash = pd.DataFrame(Prakash[['Balance','Innovation']].mean())
ScorePrakash.loc['Total']= ScorePrakash.mean()
ScorePrakash.columns = ['Prakash']

ScorePP = pd.DataFrame(PP[['Balance','Innovation']].mean())
ScorePP.loc['Total']= ScorePP.mean()
ScorePP.columns = ['PP']

ScorePE = pd.DataFrame(PE[['Balance','Innovation']].mean())
ScorePE.loc['Total']= ScorePE.mean()
ScorePE.columns = ['PE']

ScorePrintridi = pd.DataFrame(Printridi[['Balance','Innovation']].mean())
ScorePrintridi.loc['Total']= ScorePrintridi.mean()
ScorePrintridi.columns = ['Printridi']

ScoresList = pd.concat([ScoreKopernik, ScoreBambooU, ScoreNuCycle, ScoreIDEP, ScoreHydropods, ScorePrakash, ScorePP, ScorePE, ScorePrintridi.reindex(ScoreKopernik.index)], axis=1)
#Transpose
ScoresList = ScoresList.T
ScoresList
# Out:
#             Balance  Innovation     Total
# Kopernik   6.093434    6.590909  6.342172
# BambooU    5.608974    6.397436  6.003205
# NuCycle    5.905556    6.022222  5.963889
# IDEP       5.922619    6.000000  5.961310
# Hydropods  6.039474    6.228070  6.133772
# Prakash    5.916667    6.809524  6.363095
# PP         5.778455    5.491870  5.635163
# PE         6.516667    6.400000  6.458333
# Printridi  5.517730    5.411348  5.464539

# %%
print("The winner of the Fab Island Challenge 2022 is", ScoresList['Total'].idxmax())
# Out:
# The winner of the Helium grant is Prakash
# The winner of the Fab Island Challenge 2022 is PE
